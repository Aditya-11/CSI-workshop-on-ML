# %% [markdown]
# # Titanic survival project
#
#
#
# ## Questions that are to be answered.
#
# Check for the training dataset for the survivals and non-survivals in the dataset.
#
# * Checking for the attributes that cause survival and not survival by basic poltting.
#
# * Build the model from the dataset for classification of survived and     not survivied using logistic regression.
#
#
# ## Import the Libraries.
#
# In this tutorial we import "missingno" library for missing values.

# %% [markdown]
# ## Description of the dataset.
#
# <img src = des.PNG>

# %% [markdown]
# ## Load the training and testing data.
#
# Training data is named train.csv and testing data as test.csv.

# %% [markdown]
# ## View the data.

# %%
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## 1. Cleaning the data
#
# ## Check for any null values in the dataset.
#
# Using "missingno.matrix()" function.

# %% [markdown]
# ### Do you observe any missing values?
#
# Print the columns names containing missing values.

# %%
## your respose Cell.
# Out:
# Age and Cabin

# %% [markdown]
# ## Treating the missing values of cabin.

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ** There are only 204 values in the Cabin attribute out of 891.Calculate the precentage of missing values.**

# %%
# Out:
# 77.10437710437711

# %% [markdown]
# ** There are more than 65 precent data in the Cabin column is null. Therefore it is better to drop the column in the "train" and "test" dataframes that does not contribute to any predictions. **

# %% [markdown]
# ** Visualize the missing values in the train and test dataset and check for the cabin column. **
# ### For Train

# %% [markdown]
# ### For Test.

# %% [markdown]
# Great! done with 'Cabin' column.
#
# ## Treating the missing values of age with appropriate values.
#
# What is your approach? Print out the answer.

# %%
# your response cell.
# Out:
# Filling age with the mean of the class for each missing values of that particular class would be appropriate.

# %% [markdown]
# ** Find the unique classes of passengers which is "Pclass" variable of the dataframe.**

# %%
# Out:
# array([3, 1, 2])

# %% [markdown]
# ** There are three unique classess in the dataset.**
#
# ** Compute the "floor mean" of each class, as age cannot be in decimals in this case. **

# %%
# Out:
# The average Age of class 1: 38.0
# The average Age of class 2: 30.0
# The average Age of class 3: 25.0

# %% [markdown]
# ** Fill the missing values of age in the dataset with mean age computed above.**
#
# Hint: Create a custom function.

# %% [markdown]
# Great! Out data looks clean without any missing values.

# %% [markdown]
# ## Print the summary statistics of training data

# %%
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.265062    0.523008
# std     257.353842    0.486592    0.836071   13.212184    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   26.000000    0.000000
# 75%     668.500000    1.000000    3.000000   37.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ** What is the mean and standard deviation of Age? **

# %%
# Out:
#  standard deviation: 13.2121
#  Mean : 29.26

# %% [markdown]
# # 2. Exploratory data analysis

# %% [markdown]
# # Prepare the data for the model.
#
# Get th dummies for 'Sex', 'Embarked' and drop the 'Sex', 'Embarkd', 'Name', and 'Ticket' of the training data that does not contribute to the modelling.
#
# ## For training data.

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male    Q    S
# 0            1         0       3  22.0      1      0   7.2500   1.0  0.0  1.0
# 1            2         1       1  38.0      1      0  71.2833   0.0  0.0  0.0
# 2            3         1       3  26.0      0      0   7.9250   0.0  0.0  1.0
# 3            4         1       1  35.0      1      0  53.1000   0.0  0.0  1.0
# 4            5         0       3  35.0      0      0   8.0500   1.0  0.0  1.0

# %% [markdown]
# ## For testing data.

# %%
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  male    Q    S
# 0          892       3  34.5      0      0   7.8292   1.0  1.0  0.0
# 1          893       3  47.0      1      0   7.0000   0.0  0.0  1.0
# 2          894       2  62.0      0      0   9.6875   1.0  1.0  0.0
# 3          895       3  27.0      0      0   8.6625   1.0  0.0  1.0
# 4          896       3  22.0      1      1  12.2875   0.0  0.0  1.0

# %% [markdown]
# ## Fill the missing values in testing data with "0".

# %% [markdown]
# # Make train, test split

# %% [markdown]
# # Fit the data to the training dataset

# %%
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # Predict the splitted test data and unseen test data.

# %% [markdown]
# # Evaluation

# %%
# Out:
# [[135  19]
#  [ 41  73]]

# %%
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# ## Make the submissions in the format specified of sample submission.

# %% [markdown]
# ## Create the dataframe in the valid format.

# %%
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# ## Save the submissions using pandas named 'final_sub.csv'
#
# **Hint:** Use "pdandas.DataFrame.to_csv" method.
