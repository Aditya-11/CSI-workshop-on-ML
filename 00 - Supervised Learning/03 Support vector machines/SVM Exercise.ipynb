# %% [markdown]
# # Support Vector Machines Exercise
#
# For this exercise we are going to use IRIS dataset for classification.
#
# This description of the dataset is found [here](http://en.wikipedia.org/wiki/Iris_flower_data_set).
#
#
# # Step - 0
#
# Import libraries.

# %% [markdown]
# # Step - 1
#
# Load the dataset from seaborn using **sns.load_dataset('iris')**.

# %% [markdown]
# # Step - 3
#
# Exploratory data analysis.

# %% [markdown]
# # Step - 4
#
# Prepare the dataset.

# %% [markdown]
# # Step - 5
#
# Fit the data to the **SVM()** model.

# %%
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# # Step - 6
#
# Evaluate the model on the testing data.

# %%
# Out:
# [[18  0  0]
#  [ 0 12  0]
#  [ 0  0 15]]

# %%
# Out:
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        18
#  versicolor       1.00      1.00      1.00        12
#   virginica       1.00      1.00      1.00        15
#
# avg / total       1.00      1.00      1.00        45

# %% [markdown]
# ---
#                                                        THE END
